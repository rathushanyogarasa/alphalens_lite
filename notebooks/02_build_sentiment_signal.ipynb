# %% [markdown]
# # 02 Build Sentiment Signal
# Fetch GDELT headlines, score with trained FinBERT, aggregate daily sentiment factor.

# %%
import config
from src.sentiment_factor import run_sentiment_factor

scored, daily = run_sentiment_factor(
    tickers=config.TICKERS,
    lookback_days=config.GDELT_LOOKBACK_DAYS,
    save=True,
)
print(scored.shape, daily.shape)
daily.head()
