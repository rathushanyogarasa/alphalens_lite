# %% [markdown]
# # 01 Train FinBERT
# Prepare labeled data and fine-tune FinBERT.

# %%
import config
from src.data_prep import run_data_prep
from src.train import run_training

train_df, val_df, test_df = run_data_prep()
print(train_df.shape, val_df.shape, test_df.shape)

# %%
model = run_training(train_df, val_df)
print('best model saved to', config.MODEL_DIR)
